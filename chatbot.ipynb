# %%
from chatbot import run_chatbot
from llm_model import model

# %% [markdown]
# ### Exemple 1

# %%
run_chatbot(model)
# Out:
#     <div style="
#         background-color:#e3f2fd;
#         padding:10px;
#         border-radius:10px;
#         margin:5px;
#         width:60%;
#         text-align:left;
#         float:left;
#         clear:both;
#     ">
#         <b>🤖 Assistant :</b><br>
#         Bonjour ! Je suis là pour vous fournir des informations de santé générales.
#     </div>
#     <div style="
#         background-color:#d4edda;
#         padding:10px;
#         border-radius:10px;
#         margin:5px;
#         width:60%;
#         text-align:left;
#         float:right;
#         clear:both;
#     ">
#         <b>🧑 Patient :</b><br>
#         J'ai de la fièvre, quel médicament dois-je prendre ?
#     </div>
#     <div style="
#         background-color:#e3f2fd;
#         padding:10px;
#         border-radius:10px;
#         margin:5px;
#         width:60%;
#         text-align:left;
#         float:left;
#         clear:both;
#     ">
#         <b>🤖 Assistant :</b><br>
# ...

# %% [markdown]
# ### Exemple 2

# %%
run_chatbot(model)
# Out:
#     <div style="
#         background-color:#e3f2fd;
#         padding:10px;
#         border-radius:10px;
#         margin:5px;
#         width:60%;
#         text-align:left;
#         float:left;
#         clear:both;
#     ">
#         <b>🤖 Assistant :</b><br>
#         Bonjour ! Je suis là pour vous fournir des informations de santé générales.
#     </div>
#     <div style="
#         background-color:#d4edda;
#         padding:10px;
#         border-radius:10px;
#         margin:5px;
#         width:60%;
#         text-align:left;
#         float:right;
#         clear:both;
#     ">
#         <b>🧑 Patient :</b><br>
#         bonjour. j'ai mal au ventre accompagné de vomissement
#     </div>
#     <div style="
#         background-color:#e3f2fd;
#         padding:10px;
#         border-radius:10px;
#         margin:5px;
#         width:60%;
#         text-align:left;
#         float:left;
#         clear:both;
#     ">
#         <b>🤖 Assistant :</b><br>
# ...

# %% [markdown]
# ### Exemple 3

# %%
run_chatbot(model)
# Out:
#     <div style="
#         background-color:#e3f2fd;
#         padding:10px;
#         border-radius:10px;
#         margin:5px;
#         width:60%;
#         text-align:left;
#         float:left;
#         clear:both;
#     ">
#         <b>🤖 Assistant :</b><br>
#         Bonjour ! Je suis là pour vous fournir des informations de santé générales.
#     </div>
#     <div style="
#         background-color:#d4edda;
#         padding:10px;
#         border-radius:10px;
#         margin:5px;
#         width:60%;
#         text-align:left;
#         float:right;
#         clear:both;
#     ">
#         <b>🧑 Patient :</b><br>
#         bonjour. je vois du sang dans mes vomissements
#     </div>
#     <div style="
#         background-color:#e3f2fd;
#         padding:10px;
#         border-radius:10px;
#         margin:5px;
#         width:60%;
#         text-align:left;
#         float:left;
#         clear:both;
#     ">
#         <b>🤖 Assistant :</b><br>
# ...

# %%
run_chatbot(model)
# Out:
#     <div style="
#         background-color:#e3f2fd;
#         padding:10px;
#         border-radius:10px;
#         margin:5px;
#         width:60%;
#         text-align:left;
#         float:left;
#         clear:both;
#     ">
#         <b>🤖 Assistant :</b><br>
#         Bonjour ! Je suis là pour vous fournir des informations de santé générales.
#     </div>
#     <div style="
#         background-color:#d4edda;
#         padding:10px;
#         border-radius:10px;
#         margin:5px;
#         width:60%;
#         text-align:left;
#         float:right;
#         clear:both;
#     ">
#         <b>🧑 Patient :</b><br>
#         bonjour . j'i douleur en poitrine et en mes os
#     </div>
#     <div style="
#         background-color:#e3f2fd;
#         padding:10px;
#         border-radius:10px;
#         margin:5px;
#         width:60%;
#         text-align:left;
#         float:left;
#         clear:both;
#     ">
#         <b>🤖 Assistant :</b><br>
# ...
